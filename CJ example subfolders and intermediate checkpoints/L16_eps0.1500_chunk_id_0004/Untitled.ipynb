# %%
import sys
import os
import numpy as np
import scipy.sparse as sparse
import json
import warnings
warnings.filterwarnings("ignore")
import time

import matplotlib.pyplot as plt
from matplotlib.pyplot import cm

path = '/Users/cheryne/PYTHON/python_submissions_optimized/L16_eps0.1500_chunk_id_0004/'

auto_corr=np.load(path + '0_auto_correlatorZ_nonmover.npy')
auto_corr_singleHaar=np.load(path +'0_auto_correlatorZ_nonmover_singleHaar.npy')


nmin=np.load(path + '0_nmin.npy')
num_statesmin=np.load(path + '0_num_statesmin.npy')
tmin=np.load(path+'0_tmin.npy')


print(nmin)
print(num_statesmin)
print(tmin)

plt.plot(auto_corr_singleHaar[0,0:1000])
#plt.plot(np.real(np.mean(auto_corr,axis=0)))
# Out:
# 0
# 0
# 516400
